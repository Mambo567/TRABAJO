# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### **TÍTULO**

# %% [markdown]
# ##### "Transformación Energética Global: Identificando Oportunidades de Inversión en el Camino hacia la Sostenibilidad"

# %% [markdown]
# ### TEMA

# %% [markdown]
# Este proyecto analiza la transición energética global, comparando el crecimiento de energías renovables frente a las no renovables y evaluando la eficiencia energética en sectores de alto consumo. A través de un enfoque en la producción, suministro y consumo final de energía en países clave, se identifican tendencias de adopción de energías limpias y oportunidades de mejora en eficiencia energética. El análisis destaca regiones y sectores con alto potencial de inversión en infraestructura renovable y mejora en eficiencia, proporcionando información estratégica para inversores y empresarios interesados en rentabilizar la sostenibilidad y optimizar el uso de recursos energéticos.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# **Hipóstesis 1:** "Las regiones con mayor producción de energía renovable presentan oportunidades de inversión en expansión de infraestructura energética. lo que permitiría satisfacer tanto la demanda local como las exportaciones hacia regiones con menor capacidad de generación limpia. Esto generaría una ventaja competitiva en el mercado energético global, potenciando la rentabilidad y el crecimiento sostenible."

# %% [markdown]
# **Hipótesis 2:** "En regiones con alta importación de energía renovable para sectores clave como la industria y el transporte, existe una demanda insatisfecha de generación local de energía limpia. Esto sugiere que invertir en infraestructura de producción de energías renovables en estas áreas podría reducir costos de importación, aumentar la autosuficiencia energética y ofrecer una ventaja competitiva a las empresas locales."

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# #### **Fuente:** International Energy Agency (IEA) https://www.iea.org/data-and-statistics/data-sets
#
# ##### **Archivos (Preliminares):**
# - **World Energy Balances Highlights 2024:** Este dataset de la IEA proporciona datos anuales sobre balances energéticos en países de todo el mundo, desglosando la producción, importación, exportación, suministro total y consumo final de energía por tipo (renovables y no renovables) desde 1971 hasta 2023. Expresado en petajulios (PJ), permite analizar la evolución de la dependencia energética y la transición hacia energías renovables en cada región.
# - **IEA-EnergyEnd-usesandEfficiencyIndicatorsdatabase-HighlightsNovember2023:** Este dataset de la IEA proporciona datos sobre el consumo de energía en el sector residencial por país y tipo de fuente energética (como petróleo, gas, carbón y biocombustibles), desglosado por año de 2000 a 2021. Es útil para analizar la evolución en el uso de energías renovables y no renovables en hogares y su impacto en la eficiencia energética residencial. ​
# - **WorldEnergyInvestment2021_DataFile:** Este dataset de la IEA detalla la inversión global en energía desde 2015 hasta 2021, desglosada en categorías como combustibles fósiles, renovables, y otros tipos de suministro energético. Proporciona una visión general de cómo se distribuye el financiamiento en el sector energético, siendo útil para identificar tendencias de inversión en tecnologías limpias frente a fuentes convencionales.

# %%
## Visión preliminar de archivo principal. En proceso de evaluar los otros datasets.
import pandas as pd
pd.read_excel("./DATABASES/World Energy Balances Highlights 2024.xlsx",sheet_name="TimeSeries_1971-2023",header=1).head(10)
# Out:
#      Country                   Product                                   Flow  \
# 0  Australia  Coal, peat and oil shale                        Production (PJ)
# 1  Australia  Coal, peat and oil shale                           Imports (PJ)
# 2  Australia  Coal, peat and oil shale                           Exports (PJ)
# 3  Australia  Coal, peat and oil shale               Total energy supply (PJ)
# 4  Australia  Coal, peat and oil shale  Electricity, CHP and heat plants (PJ)
# 5  Australia  Coal, peat and oil shale    Oil refineries, transformation (PJ)
# 6  Australia  Coal, peat and oil shale           Total final consumption (PJ)
# 7  Australia  Coal, peat and oil shale                          Industry (PJ)
# 8  Australia  Coal, peat and oil shale                         Transport (PJ)
# 9  Australia  Coal, peat and oil shale                       Residential (PJ)
#
#        NoCountry                     NoProduct  \
# 0  01. Australia  01. Coal, peat and oil shale
# ...
